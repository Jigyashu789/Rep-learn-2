# %% [markdown]
# Tutorial - 4 Python operators

# %%
#python operators 
#Logical
#Equality
#Comparision
#Arithmethic

# %%
#Lgical operators 
# Not - Unary Negation
# AND - Conditional AND
# OR - Conditional OR

# %%
type(False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
a = True 
b = False

True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
age = int(input("Enter the age"))
if age<18 or age>=35:
    print("Successful Execution")
# Out:
# Successful Execution

# %% [markdown]
# #Equality Operators
#
# Operators
#
# is --------> a is b returns true if variable/identifiers a and b points to the same object
# is not ------> a is not b returns if variable a and b points to the different object
# == -------> a==b returns true if variable/identifiers a and b has same value
# != -----> a!=b returns true if variable/identifiers a and b has different value

# %%
a = "Krish"
b = "Krish"

a==b
# Out:
# True

# %%
a = "Krish"
b = "Krish1"

a==b
# Out:
# False

# %%
age = int(input("Enter your age: "))
if age==18:
    print("You are an adult")
# Out:
# You are an adult

# %%
#memory location

a = "Krish"
b = "Krish"
print(id(a))
print(id(b))
# Out:
# 2350775793536
# 2350775793536

# %%
a is b
# Out:
# True

# %%
lst = [1,2,3]
lst1 = [1,2,3]
print(id(lst))
print(id(lst1))
# Out:
# 2350753904448
# 2350782439232

# %%
lst == lst1
# Out:
# True

# %%
lst is lst1
# Out:
# False

# %%
lst is not lst1
# Out:
# True

# %%
"Jigyashu" != "Jigyashu1"
# Out:
# True

# %% [markdown]
# #Comparison Operators
#
# Operation
#
# < -------> less than
# <= -------> less than or equal to
# >  -------> greater than
# >= -------> greater than or equal to

# %%
marks = float(input("Enter the marks :"))

if marks>=35:
    print("pass")
    if marks>= 50 and marks <=80:
        print("First")
elif marks <35:
    print("fail")
# Out:
# pass
